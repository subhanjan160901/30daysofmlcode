# %%
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np

# %%
img = cv2.imread('C:/Users/dell/Documents/Udemy OpenCV course/rainbow.jpg')
img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# %% [markdown]
# **1.THRESH_BINARY: This merely turns any value above and below your threshold into the minimum possible and maximum potential value respectively.**
#
# **2.THRESH_BINARY_INV: This does the opposite of a THRESH_BINARY where any value above and below your threshold into the maximum possible and minimum potential value respectively.**
#
# **3.THRESH_TRUNC: Values lower than the threshold value are unchanged, but any value higher is set to the threshold value of 127.**
#
# **4.THRESH_TOZERO: Pixel values lower then the threshold value are set to the 0 and value above are unchanged.**
#
# **5.THRESH_TOZERO_INV: Pixel values less than the threshold value are fixed, and the value above is set to 0.**

# %%
plt.imshow(img, cmap='gray')

# %%
255/2
# Out:
# 127.5

# %%
ret, thresh1 = cv2.threshold(img,127,255,cv2.THRESH_BINARY)

# %%
ret
# Out:
# 127.0

# %%
plt.imshow(thresh1, cmap='gray')

# %%
ret, thresh2 = cv2.threshold(img,127,255,cv2.THRESH_BINARY_INV)

# %%
plt.imshow(thresh2, cmap='gray')

# %%
ret, thresh3 = cv2.threshold(img,127,255,cv2.THRESH_TRUNC)

# %%
plt.imshow(thresh3, cmap='gray')

# %%
ret, thresh4 = cv2.threshold(img,127,255,cv2.THRESH_TOZERO)

# %%
plt.imshow(thresh4, cmap='gray')

# %%
ret, thresh5 = cv2.threshold(img,127,255,cv2.THRESH_TOZERO_INV)

# %%
plt.imshow(thresh5, cmap='gray')

# %% [markdown]
# # Real World Applications

# %%
img = cv2.imread('C:/Users/dell/Documents/Udemy OpenCV course/crossword.jpg',0)
plt.imshow(img, cmap='gray')

# %%
def show_pic(img):
    fig = plt.figure(figsize=(15,15))
    ax = fig.add_subplot(1,1,1)
    ax.imshow(img, cmap='gray')

# %%
show_pic(img)

# %% [markdown]
# # Simple Binary

# %%
ret, th1 = cv2.threshold(img,160,255,cv2.THRESH_BINARY)
show_pic(th1)

# %%
img
# Out:
# array([[218, 219, 222, ..., 216, 217, 216],
#        [223, 220, 224, ..., 212, 214, 214],
#        [224, 225, 224, ..., 209, 210, 210],
#        ...,
#        [226, 224, 222, ..., 220, 224, 223],
#        [217, 220, 226, ..., 223, 221, 223],
#        [211, 213, 219, ..., 224, 225, 220]], dtype=uint8)

# %% [markdown]
# # Adaptive Thresholding

# %% [markdown]
# **_Simple thresholding_ is very useful for basic tasks. However, it does have its problems, mainly that it sets a threshold value globally, meaning that it is constant for the entire image. This becomes a problem if there is some lighting on the image making some areas lighters then other.**

# %% [markdown]
# https://medium.com/@anupriyam/basic-image-thresholding-in-opencv-5af9020f2472

# %%
th2 = cv2.adaptiveThreshold(img,255,cv2.ADAPTIVE_THRESH_MEAN_C,cv2.THRESH_BINARY, blockSize=11, C=8) # Play around with these last 2 numbers
show_pic(th2)

# %%
th3 = cv2.adaptiveThreshold(img,255,cv2.ADAPTIVE_THRESH_GAUSSIAN_C,cv2.THRESH_BINARY, blockSize=11, C=8) # Play around with these last 2 numbers
show_pic(th3)

# %% [markdown]
# # Blending of different thresholds

# %%
blended = cv2.addWeighted(src1=th1, src2=th2, alpha=0.7, beta=0.3, gamma=0)
show_pic(blended)

# %% [markdown]
# **FOR MORE INFO REFER TO THIS ARTICLE:**

# %% [markdown]
# https://www.tutorialspoint.com/opencv/opencv_adaptive_threshold.htm
